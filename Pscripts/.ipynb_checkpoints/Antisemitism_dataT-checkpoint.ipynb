# %%
import pandas as pd
import numpy as np
import re
import string
import nltk
from nltk.corpus import stopwords;
from nltk.stem import PorterStemmer 
from nltk.tokenize import word_tokenize;
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk import pos_tag

# %%
data=pd.read_csv("/Users/dhanushkikkisetti/Documents/Research Assistant/Antisemitism_new_datateam.csv")
data=data[['Social media post (text)','Antisemitic (Y/N)']]
data=data.dropna()
data['Antisemitism']=data['Antisemitic (Y/N)'].map({'Y':1,'N':0})
data['Antisemitic (Y/N)'].replace(['Y','N'],[1,0],inplace=True)
data.rename(columns={"Social media post (text)":"Text"},inplace=True)
data=data[['Text','Antisemitism']]
text=list(data['Text'])

# %%
def lower(text):
    return text.lower() 

def digits(text):
    return re.sub('\d','',text)

def punctuation(text):
    return text.translate(str.maketrans('','',string.punctuation))

def tokenize(text):
    return word_tokenize(text)
data['Text']=data['Text'].apply(lambda x: lower(x))
data['Text']=data['Text'].apply(lambda x: digits(x))
data['Text']=data['Text'].apply(lambda x: punctuation(x))
data['Text']=data['Text'].apply(lambda x: tokenize(x))

# %%
def remove_stopwords(text):
    stopword=set(stopwords.words('english'))
    modified_text=[]
    for i in text:
        if i not in stopword:
            modified_text.append(i)
    return modified_text

def lematize(text):
    lematizer=WordNetLemmatizer()
    lema=[]
    for i in text:
        lema.append(lematizer.lemmatize(i))
    return (" ".join(lema))

#def stemming(text):
 #   stemmer=PorterStemmer()
  #  stemm=[]
   # for i in text:
    #    stemm.append(stemmer.stem(i))
    #return (" ".join(stemm))
def bigstring(text):
    new=[]
    for i in text:
        if len(i)<12:
            new.append(i)
    return new

# %%
data['Text']=data['Text'].apply(lambda x:bigstring(x))
data['Text']=data['Text'].apply(lambda x:remove_stopwords(x))
data['Text']=data['Text'].apply(lambda x:lematize(x))
#data['Text']=data['Text'].apply(lambda x:stemming(x))
data
# Out:
#                                                  Text  Antisemitism
# 0   must read ukrainian man sharing experience war...             1
# 1   quibble semantics theyre referring frankfurt s...             1
# 2   eventually show end cancelling thats design so...             1
# 3   thats great forgot report shouldnt giving kid ...             0
# 4   getting rid influence feminism cultural marxis...             1
# 5   many redpills jew cultural marxism nwo eg wef ...             1
# 6   explain hippy lsd cultural marxism syoure real...             0
# 7   fact time magazine magazine grew would publish...             1
# 8   side trannies femoids fucking hate woman disgu...             0
# 9   everyone who old enough remember occupy know c...             1
# 10  one day tate exposed greta thunberg lie global...             1
# 11  one day tate exposed greta thunberg lie global...             1
# 12  doxxed pizza box thing fake news created trans...             1
# 13  treasonous traitor criminal career politician ...             1
# 14  nope globalist want u intertwined run elite gl...             1
# 15              globalist award served globalist king             0
# 16  gop rinos bed left ideology theyre complicit f...             1
# 17  gone globalist training program reject look dr...             0
# 18  ultra rino globalist traitor abbott dumped ill...             0
# 19     cult medic ch globalist plandemic vaccine evil             1

# %%
antisemitism_data=data[data['Antisemitism']==1]
antisemitism_data=list(antisemitism_data['Text'])
antisemitism_data
# Out:
# ['must read ukrainian man sharing experience war instructive potentially expect war break prepare entire generation swallowed spitted revolution war cultural marxism fake pandemic war thing want retribution globalist caused ht cigtelegram via',
#  'quibble semantics theyre referring frankfurt school sometimes labeled cultural marxism',
#  'eventually show end cancelling thats design social equity critical race theory aka cultural marxism next evolution asexual clone everything difference extinct',
#  'getting rid influence feminism cultural marxism would good start mental illness loneliness wasnt anywhere near bad itd become result ideology directly hostile west',
#  'many redpills jew cultural marxism nwo eg wef ruling bloodline kalergi plan white replacement etc feel demoralized could sake world know must individual dont want live dystopian far',
#  'fact time magazine magazine grew would publish article go show low they‚äôve fallen pit cultural marxism leftist believe shite remember',
#  'everyone who old enough remember occupy know cultural marxism took education way earlier already problem',
#  'one day tate exposed greta thunberg lie globalist lie brain wash teen climate change tax sun hot number one searched man world wide net tate arrested next day human trafficking coincidence globalist rothschild created climate change back early bohemian grove created climate change greta thunberg svante arrhenius created greenhouse theory part bohemian grove gathering placed family green house gas guru coincidence d came tate exposed greta teen climate hoax saying using teen bring taxation human sun hot \uf8ffüòç man quick deep state cabal arrested tate everything say go viral',
#  'one day tate exposed greta thunberg lie globalist lie brain wash teen climate change tax sun hot number one searched man world wide net tate arrested next day human trafficking coincidence globalist rothschild created climate change back early bohemian grove created climate change greta thunberg svante arrhenius created greenhouse theory part bohemian grove gathering placed family green house gas guru coincidence d came tate exposed greta teen climate hoax saying using teen bring taxation human sun hot \uf8ffüòç man quick deep state cabal arrested tate everything say go viral',
#  'doxxed pizza box thing fake news created transgender wokeist even tate tool still dont wish arrest execution simply speaking globalist cabal huge influence toward younger generation openly talk satanic globalist cabal must destroyed',
#  'treasonous traitor criminal career politician thug deep state thug globalist thug abc agency fbi cia wef world economic forum need destroyed toppled taken taken fyi deep state thug globalist cabal bstrds reap sownsin take farther want go keep longer want stay make pay way want pay keep good fight alex show¬†more',
#  'nope globalist want u intertwined run elite globalist dont lay tariff friend stupid fu',
#  'gop rinos bed left ideology theyre complicit fraud america people support perversion truth destroy america world beacon godly freedom power fix perk get powerful position authority globalist con fight secure criminal mean necessary matter many life agenda destroys liar dont believe god offer mercy merciless theyre embattled innocent womb young old view life either u',
#  'cult medic ch globalist plandemic vaccine evil']

# %%
vectorizer=TfidfVectorizer(ngram_range=(1,1))
tfidf=vectorizer.fit_transform(antisemitism_data)
feature_name=vectorizer.get_feature_names_out()
tfidf[1,34]
# Out:
# 0.0

# %%
a=0.1
b=[]
for i in range(tfidf.shape[0]):
    for j in range(tfidf.shape[1]):
        if tfidf[i,j]<0.1:
            b.append(feature_name[j])

pos_tag(b)
# Out:
# [('abc', 'NN'),
#  ('agency', 'NN'),
#  ('agenda', 'RB'),
#  ('aka', 'JJ'),
#  ('alex', 'JJ'),
#  ('already', 'RB'),
#  ('america', 'RB'),
#  ('anywhere', 'RB'),
#  ('arrest', 'RB'),
#  ('arrested', 'VBN'),
#  ('arrhenius', 'JJ'),
#  ('article', 'NN'),
#  ('asexual', 'JJ'),
#  ('authority', 'NN'),
#  ('back', 'RB'),
#  ('bad', 'JJ'),
#  ('beacon', 'NN'),
#  ('become', 'NN'),
#  ('bed', 'VBD'),
#  ('believe', 'JJ'),
#  ('bloodline', 'NN'),
#  ('bohemian', 'JJ'),
#  ('box', 'NN'),
#  ('brain', 'NN'),
#  ('bring', 'NN'),
#  ('bstrds', 'NNS'),
#  ('cabal', 'JJ'),
#  ('came', 'VBD'),
#  ('cancelling', 'VBG'),
#  ('career', 'NN'),
#  ('ch', 'NN'),
#  ('change', 'NN'),
#  ('cia', 'NN'),
#  ('climate', 'NN'),
#  ('clone', 'NN'),
#  ('coincidence', 'NN'),
#  ('complicit', 'NN'),
#  ('con', 'NN'),
#  ('could', 'MD'),
#  ('created', 'VB'),
#  ('criminal', 'JJ'),
#  ('critical', 'JJ'),
#  ('cult', 'NN'),
#  ('cultural', 'JJ'),
#  ('day', 'NN'),
#  ('deep', 'JJ'),
#  ('demoralized', 'VBN'),
#  ('design', 'NN'),
#  ('destroy', 'NN'),
#  ('destroyed', 'VBD'),
#  ('destroys', 'JJ'),
#  ('difference', 'NN'),
#  ('directly', 'RB'),
#  ('dont', 'VBZ'),
#  ('doxxed', 'JJ'),
#  ('dystopian', 'JJ'),
#  ('earlier', 'JJR'),
#  ('early', 'JJ'),
#  ('economic', 'JJ'),
#  ('education', 'NN'),
#  ('eg', 'NN'),
#  ('either', 'CC'),
#  ('elite', 'NN'),
#  ('embattled', 'JJ'),
#  ('end', 'NN'),
#  ('enough', 'JJ'),
#  ('equity', 'NN'),
#  ('etc', 'FW'),
#  ('even', 'RB'),
#  ('eventually', 'RB'),
#  ('everyone', 'NN'),
#  ('everything', 'NN'),
#  ('evil', 'JJ'),
#  ('evolution', 'NN'),
#  ('execution', 'NN'),
#  ('exposed', 'VBD'),
#  ('extinct', 'JJ'),
#  ('fact', 'NN'),
#  ('fallen', 'VBN'),
#  ('family', 'NN'),
#  ('far', 'RB'),
#  ('farther', 'RB'),
#  ('fbi', 'JJ'),
#  ('feel', 'NN'),
#  ('feminism', 'NN'),
#  ('fight', 'VBD'),
#  ('fix', 'JJ'),
#  ('forum', 'NN'),
#  ('frankfurt', 'NN'),
#  ('fraud', 'NN'),
#  ('freedom', 'NN'),
#  ('friend', 'NN'),
#  ('fu', 'NN'),
#  ('fyi', 'NN'),
#  ('gas', 'NN'),
#  ('gathering', 'NN'),
#  ('get', 'NN'),
#  ('getting', 'VBG'),
#  ('globalist', 'NN'),
#  ('go', 'VBP'),
#  ('god', 'RB'),
#  ('godly', 'RB'),
#  ('good', 'JJ'),
#  ('gop', 'NN'),
#  ('green', 'JJ'),
#  ('greenhouse', 'NN'),
#  ('greta', 'NN'),
#  ('grew', 'VBD'),
#  ('grove', 'JJ'),
#  ('guru', 'NN'),
#  ('hoax', 'NN'),
#  ('hostile', 'JJ'),
#  ('hot', 'JJ'),
#  ('house', 'NN'),
#  ('huge', 'JJ'),
#  ('human', 'JJ'),
#  ('ideology', 'NN'),
#  ('illness', 'NN'),
#  ('individual', 'JJ'),
#  ('influence', 'NN'),
#  ('innocent', 'NN'),
#  ('intertwined', 'VBD'),
#  ('itd', 'JJ'),
#  ('jew', 'NN'),
#  ('kalergi', 'NN'),
#  ('keep', 'VB'),
#  ('know', 'NN'),
#  ('labeled', 'VBN'),
#  ('lay', 'NN'),
#  ('left', 'VBD'),
#  ('leftist', 'JJ'),
#  ('liar', 'NN'),
#  ('lie', 'JJ'),
#  ('life', 'NN'),
#  ('live', 'JJ'),
#  ('loneliness', 'RB'),
#  ('longer', 'RB'),
#  ('low', 'JJ'),
#  ('magazine', 'NN'),
#  ('make', 'VBP'),
#  ('many', 'JJ'),
#  ('marxism', 'NN'),
#  ('matter', 'NN'),
#  ('mean', 'VBP'),
#  ('medic', 'JJ'),
#  ('mental', 'JJ'),
#  ('merciless', 'NN'),
#  ('mercy', 'NN'),
#  ('more', 'RBR'),
#  ('near', 'IN'),
#  ('necessary', 'JJ'),
#  ('need', 'VBP'),
#  ('net', 'JJ'),
#  ('news', 'NN'),
#  ('next', 'IN'),
#  ('nope', 'NN'),
#  ('number', 'NN'),
#  ('nwo', 'JJ'),
#  ('occupy', 'NN'),
#  ('offer', 'NN'),
#  ('old', 'JJ'),
#  ('one', 'CD'),
#  ('openly', 'RB'),
#  ('part', 'NN'),
#  ('pay', 'NN'),
#  ('people', 'NNS'),
#  ('perk', 'VBP'),
#  ('perversion', 'NN'),
#  ('pit', 'NN'),
#  ('pizza', 'NN'),
#  ('placed', 'VBD'),
#  ('plan', 'NN'),
#  ('plandemic', 'JJ'),
#  ('politician', 'JJ'),
#  ('position', 'NN'),
#  ('power', 'NN'),
#  ('powerful', 'JJ'),
#  ('problem', 'NN'),
#  ('publish', 'NN'),
#  ('quibble', 'JJ'),
#  ('quick', 'JJ'),
#  ('race', 'NN'),
#  ('reap', 'NN'),
#  ('redpills', 'NNS'),
#  ('referring', 'VBG'),
#  ('remember', 'VB'),
#  ('replacement', 'JJ'),
#  ('result', 'NN'),
#  ('rid', 'JJ'),
#  ('rinos', 'NNS'),
#  ('rothschild', 'VBP'),
#  ('ruling', 'VBG'),
#  ('run', 'VB'),
#  ('sake', 'JJ'),
#  ('satanic', 'JJ'),
#  ('say', 'VBP'),
#  ('saying', 'VBG'),
#  ('school', 'NN'),
#  ('searched', 'VBD'),
#  ('secure', 'NN'),
#  ('semantics', 'NNS'),
#  ('shite', 'VBP'),
#  ('show', 'NN'),
#  ('simply', 'RB'),
#  ('social', 'JJ'),
#  ('sometimes', 'RB'),
#  ('sownsin', 'JJ'),
#  ('speaking', 'VBG'),
#  ('start', 'NN'),
#  ('state', 'NN'),
#  ('stay', 'NN'),
#  ('still', 'RB'),
#  ('stupid', 'JJ'),
#  ('sun', 'JJ'),
#  ('support', 'NN'),
#  ('svante', 'NNS'),
#  ('take', 'VBP'),
#  ('taken', 'VBN'),
#  ('talk', 'NN'),
#  ('tariff', 'NN'),
#  ('tate', 'NN'),
#  ('tax', 'NN'),
#  ('taxation', 'NN'),
#  ('teen', 'NN'),
#  ('thats', 'NNS'),
#  ('theory', 'VBP'),
#  ('they', 'PRP'),
#  ('theyre', 'VBP'),
#  ('thug', 'JJ'),
#  ('thunberg', 'JJ'),
#  ('time', 'NN'),
#  ('took', 'VBD'),
#  ('tool', 'NN'),
#  ('toppled', 'VBN'),
#  ('toward', 'IN'),
#  ('trafficking', 'VBG'),
#  ('traitor', 'NN'),
#  ('transgender', 'NN'),
#  ('treasonous', 'JJ'),
#  ('truth', 'NN'),
#  ('using', 'VBG'),
#  ('vaccine', 'JJ'),
#  ('view', 'NN'),
#  ('viral', 'JJ'),
#  ('wash', 'NN'),
#  ('wasnt', 'NN'),
#  ('way', 'NN'),
#  ('wef', 'JJ'),
#  ('west', 'JJS'),
#  ('white', 'JJ'),
#  ('who', 'WP'),
#  ('wide', 'JJ'),
#  ('wish', 'JJ'),
#  ('wokeist', 'NN'),
#  ('womb', 'NN'),
#  ('world', 'NN'),
#  ('would', 'MD'),
#  ('young', 'JJ'),
#  ('younger', 'JJR'),
#  ('äôve', 'JJ'),
#  ('üòç', 'NNP'),
#  ('abc', 'NN'),
#  ('agency', 'NN'),
#  ('agenda', 'RB'),
#  ('aka', 'JJ'),
#  ('alex', 'JJ'),
#  ('already', 'RB'),
#  ('america', 'RB'),
#  ('anywhere', 'RB'),
#  ('arrest', 'RB'),
#  ('arrested', 'VBN'),
#  ('arrhenius', 'JJ'),
#  ('article', 'NN'),
#  ('asexual', 'JJ'),
#  ('authority', 'NN'),
#  ('back', 'RB'),
#  ('bad', 'JJ'),
#  ('beacon', 'NN'),
#  ('become', 'NN'),
#  ('bed', 'VBD'),
#  ('believe', 'JJ'),
#  ('bloodline', 'NN'),
#  ('bohemian', 'JJ'),
#  ('box', 'NN'),
#  ('brain', 'NN'),
#  ('break', 'NN'),
#  ('bring', 'NN'),
#  ('bstrds', 'NNS'),
#  ('cabal', 'JJ'),
#  ('came', 'VBD'),
#  ('cancelling', 'VBG'),
#  ('career', 'NN'),
#  ('caused', 'VBD'),
#  ('ch', 'JJ'),
#  ('change', 'NN'),
#  ('cia', 'NN'),
#  ('cigtelegram', 'NN'),
#  ('climate', 'NN'),
#  ('clone', 'NN'),
#  ('coincidence', 'NN'),
#  ('complicit', 'NN'),
#  ('con', 'NN'),
#  ('could', 'MD'),
#  ('created', 'VB'),
#  ('criminal', 'JJ'),
#  ('critical', 'JJ'),
#  ('cult', 'NN'),
#  ('day', 'NN'),
#  ('deep', 'JJ'),
#  ('demoralized', 'VBN'),
#  ('design', 'NN'),
#  ('destroy', 'NN'),
#  ('destroyed', 'VBD'),
#  ('destroys', 'JJ'),
#  ('difference', 'NN'),
#  ('directly', 'RB'),
#  ('dont', 'VBZ'),
#  ('doxxed', 'JJ'),
#  ('dystopian', 'JJ'),
#  ('earlier', 'JJR'),
#  ('early', 'JJ'),
#  ('economic', 'JJ'),
#  ('education', 'NN'),
#  ('eg', 'NN'),
#  ('either', 'CC'),
#  ('elite', 'NN'),
#  ('embattled', 'JJ'),
#  ('end', 'NN'),
#  ('enough', 'JJ'),
#  ('entire', 'JJ'),
#  ('equity', 'NN'),
#  ('etc', 'NN'),
#  ('even', 'RB'),
#  ('eventually', 'RB'),
#  ('everyone', 'NN'),
#  ('everything', 'NN'),
#  ('evil', 'JJ'),
#  ('evolution', 'NN'),
#  ('execution', 'NN'),
#  ('expect', 'VBP'),
#  ('experience', 'NN'),
#  ('exposed', 'VBN'),
#  ('extinct', 'JJ'),
#  ('fact', 'NN'),
#  ('fake', 'VB'),
#  ('fallen', 'VBN'),
#  ('family', 'NN'),
#  ('far', 'RB'),
#  ('farther', 'RB'),
#  ('fbi', 'JJ'),
#  ('feel', 'NN'),
#  ('feminism', 'NN'),
#  ('fight', 'VBD'),
#  ('fix', 'JJ'),
#  ('forum', 'NN'),
#  ('fraud', 'NN'),
#  ('freedom', 'NN'),
#  ('friend', 'NN'),
#  ('fu', 'NN'),
#  ('fyi', 'NN'),
#  ('gas', 'NN'),
#  ('gathering', 'NN'),
#  ('generation', 'NN'),
#  ('get', 'VB'),
#  ('getting', 'VBG'),
#  ('globalist', 'JJ'),
#  ('go', 'VB'),
#  ('god', 'JJ'),
#  ('godly', 'RB'),
#  ('good', 'JJ'),
#  ('gop', 'NN'),
#  ('green', 'JJ'),
#  ('greenhouse', 'NN'),
#  ('greta', 'NN'),
#  ('grew', 'VBD'),
#  ('grove', 'JJ'),
#  ('guru', 'NN'),
#  ('hoax', 'NN'),
#  ('hostile', 'JJ'),
#  ('hot', 'JJ'),
#  ('house', 'NN'),
#  ('ht', 'VBD'),
#  ('huge', 'JJ'),
#  ('human', 'JJ'),
#  ('ideology', 'NN'),
#  ('illness', 'NN'),
#  ('individual', 'JJ'),
#  ('influence', 'NN'),
#  ('innocent', 'JJ'),
#  ('instructive', 'NN'),
#  ('intertwined', 'VBN'),
#  ('itd', 'JJ'),
#  ('jew', 'NN'),
#  ('kalergi', 'NN'),
#  ('keep', 'VB'),
#  ('know', 'JJ'),
#  ('lay', 'NN'),
#  ('left', 'VBD'),
#  ('leftist', 'JJ'),
#  ('liar', 'NN'),
#  ('lie', 'JJ'),
#  ('life', 'NN'),
#  ('live', 'JJ'),
#  ('loneliness', 'RB'),
#  ('longer', 'RB'),
#  ('low', 'JJ'),
#  ('magazine', 'NN'),
#  ('make', 'VBP'),
#  ('man', 'NN'),
#  ('many', 'JJ'),
#  ('matter', 'NN'),
#  ('mean', 'VBP'),
#  ('medic', 'JJ'),
#  ('mental', 'JJ'),
#  ('merciless', 'NN'),
#  ('mercy', 'NN'),
#  ('more', 'RBR'),
#  ('must', 'MD'),
#  ('near', 'IN'),
#  ('necessary', 'JJ'),
#  ('need', 'VBP'),
#  ('net', 'JJ'),
#  ('news', 'NN'),
#  ('next', 'IN'),
#  ('nope', 'NN'),
#  ('number', 'NN'),
#  ('nwo', 'JJ'),
#  ('occupy', 'NN'),
#  ('offer', 'NN'),
#  ('old', 'JJ'),
#  ('one', 'CD'),
#  ('openly', 'RB'),
#  ('pandemic', 'JJ'),
#  ('part', 'NN'),
#  ('pay', 'NN'),
#  ('people', 'NNS'),
#  ('perk', 'VBP'),
#  ('perversion', 'NN'),
#  ('pit', 'NN'),
#  ('pizza', 'NN'),
#  ('placed', 'VBD'),
#  ('plan', 'NN'),
#  ('plandemic', 'JJ'),
#  ('politician', 'JJ'),
#  ('position', 'NN'),
#  ('potentially', 'RB'),
#  ('power', 'NN'),
#  ('powerful', 'JJ'),
#  ('prepare', 'NN'),
#  ('problem', 'NN'),
#  ('publish', 'JJ'),
#  ('quick', 'JJ'),
#  ('race', 'NN'),
#  ('read', 'VBD'),
#  ('reap', 'JJ'),
#  ('redpills', 'NNS'),
#  ('remember', 'VBP'),
#  ('replacement', 'JJ'),
#  ('result', 'NN'),
#  ('retribution', 'NN'),
#  ('revolution', 'NN'),
#  ('rid', 'JJ'),
#  ('rinos', 'NNS'),
#  ('rothschild', 'VBP'),
#  ('ruling', 'VBG'),
#  ('run', 'VB'),
#  ('sake', 'JJ'),
#  ('satanic', 'JJ'),
#  ('say', 'VBP'),
#  ('saying', 'VBG'),
#  ('searched', 'VBN'),
#  ('secure', 'NN'),
#  ('sharing', 'VBG'),
#  ('shite', 'JJ'),
#  ('show', 'NN'),
#  ('simply', 'RB'),
#  ('social', 'JJ'),
#  ('sownsin', 'NN'),
#  ('speaking', 'NN'),
#  ('spitted', 'VBD'),
#  ('start', 'JJ'),
#  ('state', 'NN'),
#  ('stay', 'NN'),
#  ('still', 'RB'),
#  ('stupid', 'JJ'),
#  ('sun', 'JJ'),
#  ('support', 'NN'),
#  ('svante', 'NN'),
#  ('swallowed', 'VBD'),
#  ('take', 'VB'),
#  ('taken', 'VBN'),
#  ('talk', 'NN'),
#  ('tariff', 'NN'),
#  ('tate', 'NN'),
#  ('tax', 'NN'),
#  ('taxation', 'NN'),
#  ('teen', 'NN'),
#  ('thats', 'NNS'),
#  ('theory', 'VBP'),
#  ('they', 'PRP'),
#  ('thing', 'NN'),
#  ('thug', 'NN'),
#  ('thunberg', 'NN'),
#  ('time', 'NN'),
#  ('took', 'VBD'),
#  ('tool', 'NN'),
#  ('toppled', 'VBN'),
#  ('toward', 'IN'),
#  ('trafficking', 'VBG'),
#  ('traitor', 'NN'),
#  ('transgender', 'NN'),
#  ('treasonous', 'JJ'),
#  ('truth', 'NN'),
#  ('ukrainian', 'JJ'),
#  ('using', 'VBG'),
#  ('vaccine', 'JJ'),
#  ('via', 'IN'),
#  ('view', 'NN'),
#  ('viral', 'JJ'),
#  ('want', 'VBP'),
#  ('war', 'NN'),
#  ('wash', 'NN'),
#  ('wasnt', 'VBD'),
#  ('way', 'NN'),
#  ('wef', 'NN'),
#  ('west', 'JJS'),
#  ('white', 'JJ'),
#  ('who', 'WP'),
#  ('wide', 'JJ'),
#  ('wish', 'JJ'),
#  ('wokeist', 'NN'),
#  ('womb', 'NN'),
#  ('world', 'NN'),
#  ('would', 'MD'),
#  ('young', 'JJ'),
#  ('younger', 'JJR'),
#  ('äôve', 'JJ'),
#  ('üòç', 'NNP'),
#  ('abc', 'NN'),
#  ('agency', 'NN'),
#  ('agenda', 'RB'),
#  ('alex', 'JJ'),
#  ('already', 'RB'),
#  ('america', 'RB'),
#  ('anywhere', 'RB'),
#  ('arrest', 'RB'),
#  ('arrested', 'VBN'),
#  ('arrhenius', 'JJ'),
#  ('article', 'NN'),
#  ('authority', 'NN'),
#  ('back', 'RB'),
#  ('bad', 'JJ'),
#  ('beacon', 'NN'),
#  ('become', 'NN'),
#  ('bed', 'VBD'),
#  ('believe', 'JJ'),
#  ('bloodline', 'NN'),
#  ('bohemian', 'JJ'),
#  ('box', 'NN'),
#  ('brain', 'NN'),
#  ('break', 'NN'),
#  ('bring', 'NN'),
#  ('bstrds', 'NNS'),
#  ('cabal', 'JJ'),
#  ('came', 'VBD'),
#  ('career', 'NN'),
#  ('caused', 'VBN'),
#  ('ch', 'JJ'),
#  ('change', 'NN'),
#  ('cia', 'NN'),
#  ('cigtelegram', 'NN'),
#  ('climate', 'NN'),
#  ('coincidence', 'NN'),
#  ('complicit', 'NN'),
#  ('con', 'NN'),
#  ('could', 'MD'),
#  ('created', 'VB'),
#  ('criminal', 'JJ'),
#  ('cult', 'NN'),
#  ('day', 'NN'),
#  ('deep', 'VB'),
#  ('demoralized', 'VBN'),
#  ('destroy', 'JJ'),
#  ('destroyed', 'JJ'),
#  ('destroys', 'VBZ'),
#  ('directly', 'RB'),
#  ('dont', 'JJ'),
#  ('doxxed', 'NN'),
#  ('dystopian', 'JJ'),
#  ('earlier', 'RBR'),
#  ('early', 'JJ'),
#  ('economic', 'JJ'),
#  ('education', 'NN'),
#  ('eg', 'NN'),
#  ('either', 'CC'),
#  ('elite', 'NN'),
#  ('embattled', 'VBD'),
#  ('enough', 'RB'),
#  ('entire', 'JJ'),
#  ('etc', 'FW'),
#  ('even', 'RB'),
#  ('everyone', 'NN'),
#  ('evil', 'JJ'),
#  ('execution', 'NN'),
#  ('expect', 'VBP'),
#  ('experience', 'NN'),
#  ('exposed', 'VBN'),
#  ('fact', 'NN'),
#  ('fake', 'VB'),
#  ('fallen', 'VBN'),
#  ('family', 'NN'),
#  ('far', 'RB'),
#  ('farther', 'RB'),
#  ('fbi', 'JJ'),
#  ('feel', 'NN'),
#  ('feminism', 'NN'),
#  ('fight', 'VBD'),
#  ('fix', 'JJ'),
#  ('forum', 'NN'),
#  ('frankfurt', 'NN'),
#  ('fraud', 'NN'),
#  ('freedom', 'NN'),
#  ('friend', 'NN'),
#  ('fu', 'NN'),
#  ('fyi', 'NN'),
#  ('gas', 'NN'),
#  ('gathering', 'NN'),
#  ('generation', 'NN'),
#  ('get', 'VB'),
#  ('getting', 'VBG'),
#  ('globalist', 'JJ'),
#  ('go', 'VB'),
#  ('god', 'JJ'),
#  ('godly', 'RB'),
#  ('good', 'JJ'),
#  ('gop', 'NN'),
#  ('green', 'JJ'),
#  ('greenhouse', 'NN'),
#  ('greta', 'NN'),
#  ('grew', 'VBD'),
#  ('grove', 'JJ'),
#  ('guru', 'NN'),
#  ('hoax', 'NN'),
#  ('hostile', 'JJ'),
#  ('hot', 'JJ'),
#  ('house', 'NN'),
#  ('ht', 'VBD'),
#  ('huge', 'JJ'),
#  ('human', 'JJ'),
#  ('ideology', 'NN'),
#  ('illness', 'NN'),
#  ('individual', 'JJ'),
#  ('influence', 'NN'),
#  ('innocent', 'JJ'),
#  ('instructive', 'NN'),
#  ('intertwined', 'VBN'),
#  ('itd', 'JJ'),
#  ('jew', 'NN'),
#  ('kalergi', 'NN'),
#  ('keep', 'VB'),
#  ('know', 'NN'),
#  ('labeled', 'VBN'),
#  ('lay', 'NN'),
#  ('left', 'VBD'),
#  ('leftist', 'JJ'),
#  ('liar', 'NN'),
#  ('lie', 'JJ'),
#  ('life', 'NN'),
#  ('live', 'JJ'),
#  ('loneliness', 'RB'),
#  ('longer', 'RB'),
#  ('low', 'JJ'),
#  ('magazine', 'NN'),
#  ('make', 'VBP'),
#  ('man', 'NN'),
#  ('many', 'JJ'),
#  ('matter', 'NN'),
#  ('mean', 'VBP'),
#  ('medic', 'JJ'),
#  ('mental', 'JJ'),
#  ('merciless', 'NN'),
#  ('mercy', 'NN'),
#  ('more', 'RBR'),
#  ('must', 'MD'),
#  ('near', 'IN'),
#  ('necessary', 'JJ'),
#  ('need', 'VBP'),
#  ('net', 'JJ'),
#  ('news', 'NN'),
#  ('nope', 'NN'),
#  ('number', 'NN'),
#  ('nwo', 'JJ'),
#  ('occupy', 'NN'),
#  ('offer', 'NN'),
#  ('old', 'JJ'),
#  ('one', 'CD'),
#  ('openly', 'RB'),
#  ('pandemic', 'JJ'),
#  ('part', 'NN'),
#  ('pay', 'NN'),
#  ('people', 'NNS'),
#  ('perk', 'VBP'),
#  ('perversion', 'NN'),
#  ('pit', 'NN'),
#  ('pizza', 'NN'),
#  ('placed', 'VBD'),
#  ('plan', 'NN'),
#  ('plandemic', 'JJ'),
#  ('politician', 'JJ'),
#  ('position', 'NN'),
#  ('potentially', 'RB'),
#  ('power', 'NN'),
#  ('powerful', 'JJ'),
#  ('prepare', 'NN'),
#  ('problem', 'NN'),
#  ('publish', 'NN'),
#  ('quibble', 'JJ'),
#  ('quick', 'JJ'),
#  ('read', 'NN'),
#  ('reap', 'NN'),
#  ('redpills', 'NNS'),
#  ('referring', 'VBG'),
#  ('remember', 'VB'),
#  ('replacement', 'JJ'),
#  ('result', 'NN'),
#  ('retribution', 'NN'),
#  ('revolution', 'NN'),
#  ('rid', 'JJ'),
#  ('rinos', 'NNS'),
#  ('rothschild', 'VBP'),
#  ('ruling', 'VBG'),
#  ('run', 'VB'),
#  ('sake', 'JJ'),
#  ('satanic', 'JJ'),
#  ('say', 'VBP'),
#  ('saying', 'VBG'),
#  ('school', 'NN'),
#  ('searched', 'VBD'),
#  ('secure', 'NN'),
#  ('semantics', 'NNS'),
#  ('sharing', 'VBG'),
#  ('shite', 'NN'),
#  ('simply', 'RB'),
#  ('sometimes', 'RB'),
#  ('sownsin', 'JJ'),
#  ('speaking', 'NN'),
#  ('spitted', 'VBD'),
#  ('start', 'JJ'),
#  ('state', 'NN'),
#  ('stay', 'NN'),
#  ('still', 'RB'),
#  ('stupid', 'JJ'),
#  ('sun', 'JJ'),
#  ('support', 'NN'),
#  ('svante', 'NN'),
#  ('swallowed', 'VBD'),
#  ('take', 'VB'),
#  ('taken', 'VBN'),
#  ('talk', 'NN'),
#  ('tariff', 'NN'),
#  ('tate', 'NN'),
#  ('tax', 'NN'),
#  ('taxation', 'NN'),
#  ('teen', 'IN'),
#  ('they', 'PRP'),
#  ('theyre', 'VBP'),
#  ('thing', 'NN'),
#  ('thug', 'NN'),
#  ('thunberg', 'NN'),
#  ('time', 'NN'),
#  ('took', 'VBD'),
#  ('tool', 'NN'),
#  ('toppled', 'VBN'),
#  ('toward', 'IN'),
#  ('trafficking', 'VBG'),
#  ('traitor', 'NN'),
#  ('transgender', 'NN'),
#  ('treasonous', 'JJ'),
#  ('truth', 'NN'),
#  ('ukrainian', 'JJ'),
#  ('using', 'VBG'),
#  ('vaccine', 'JJ'),
#  ('via', 'IN'),
#  ('view', 'NN'),
#  ('viral', 'JJ'),
#  ('want', 'VBP'),
#  ('war', 'NN'),
#  ('wash', 'NN'),
#  ('wasnt', 'VBD'),
#  ('way', 'NN'),
#  ('wef', 'NN'),
#  ('west', 'JJS'),
#  ('white', 'JJ'),
#  ('who', 'WP'),
#  ('wide', 'JJ'),
#  ('wish', 'JJ'),
#  ('wokeist', 'NN'),
#  ('womb', 'NN'),
#  ('world', 'NN'),
#  ('would', 'MD'),
#  ('young', 'JJ'),
#  ('younger', 'JJR'),
#  ('äôve', 'JJ'),
#  ('üòç', 'NNP'),
#  ('abc', 'NN'),
#  ('agency', 'NN'),
#  ('agenda', 'RB'),
#  ('aka', 'JJ'),
#  ('alex', 'JJ'),
#  ('already', 'RB'),
#  ('america', 'JJ'),
#  ('arrest', 'NN'),
#  ('arrested', 'VBN'),
#  ('arrhenius', 'JJ'),
#  ('article', 'NN'),
#  ('asexual', 'JJ'),
#  ('authority', 'NN'),
#  ('back', 'RB'),
#  ('beacon', 'NN'),
#  ('bed', 'NN'),
#  ('believe', 'VBP'),
#  ('bloodline', 'NN'),
#  ('bohemian', 'JJ'),
#  ('box', 'NN'),
#  ('brain', 'NN'),
#  ('break', 'NN'),
#  ('bring', 'NN'),
#  ('bstrds', 'NNS'),
#  ('cabal', 'JJ'),
#  ('came', 'VBD'),
#  ('cancelling', 'VBG'),
#  ('career', 'NN'),
#  ('caused', 'VBD'),
#  ('ch', 'JJ'),
#  ('change', 'NN'),
#  ('cia', 'NN'),
#  ('cigtelegram', 'NN'),
#  ('climate', 'NN'),
#  ('clone', 'NN'),
#  ('coincidence', 'NN'),
#  ('complicit', 'NN'),
#  ('con', 'NN'),
#  ('could', 'MD'),
#  ('created', 'VB'),
#  ('criminal', 'JJ'),
#  ('critical', 'JJ'),
#  ('cult', 'NN'),
#  ('day', 'NN'),
#  ('deep', 'JJ'),
#  ('demoralized', 'VBN'),
#  ('design', 'NN'),
#  ('destroy', 'NN'),
#  ('destroyed', 'VBD'),
#  ('destroys', 'JJ'),
#  ('difference', 'NN'),
#  ('dont', 'NN'),
#  ('doxxed', 'VBD'),
#  ('dystopian', 'JJ'),
#  ('earlier', 'RBR'),
#  ('early', 'JJ'),
#  ('economic', 'JJ'),
#  ('education', 'NN'),
#  ('eg', 'NN'),
#  ('either', 'CC'),
#  ('elite', 'NN'),
#  ('embattled', 'JJ'),
#  ('end', 'NN'),
#  ('enough', 'JJ'),
#  ('entire', 'JJ'),
#  ('equity', 'NN'),
#  ('etc', 'NN'),
#  ('even', 'RB'),
#  ('eventually', 'RB'),
#  ('everyone', 'NN'),
#  ('everything', 'NN'),
#  ('evil', 'JJ'),
#  ('evolution', 'NN'),
#  ('execution', 'NN'),
#  ('expect', 'VBP'),
#  ('experience', 'NN'),
#  ('exposed', 'VBN'),
#  ('extinct', 'JJ'),
#  ('fact', 'NN'),
#  ('fake', 'VB'),
#  ('fallen', 'VBN'),
#  ('family', 'NN'),
#  ('far', 'RB'),
#  ('farther', 'RB'),
#  ('fbi', 'JJ'),
#  ('feel', 'NN'),
#  ('fight', 'VBD'),
#  ('fix', 'JJ'),
#  ('forum', 'NN'),
#  ('frankfurt', 'NN'),
#  ('fraud', 'NN'),
#  ('freedom', 'NN'),
#  ('friend', 'NN'),
#  ('fu', 'NN'),
#  ('fyi', 'NN'),
#  ('gas', 'NN'),
#  ('gathering', 'NN'),
#  ('generation', 'NN'),
#  ('get', 'VB'),
#  ('globalist', 'JJ'),
#  ('go', 'VB'),
#  ('god', 'JJ'),
#  ('godly', 'RB'),
#  ('gop', 'VBP'),
#  ('green', 'JJ'),
#  ('greenhouse', 'NN'),
#  ('greta', 'NN'),
#  ('grew', 'VBD'),
#  ('grove', 'JJ'),
#  ('guru', 'NN'),
#  ('hoax', 'NN'),
#  ('hot', 'JJ'),
#  ('house', 'NN'),
#  ('ht', 'VBD'),
#  ('huge', 'JJ'),
#  ('human', 'JJ'),
#  ('individual', 'JJ'),
#  ('innocent', 'NN'),
#  ('instructive', 'NN'),
#  ('intertwined', 'VBD'),
#  ('jew', 'NN'),
#  ('kalergi', 'NN'),
#  ('keep', 'VB'),
#  ('know', 'NN'),
#  ('labeled', 'VBN'),
#  ('lay', 'NN'),
#  ('left', 'VBD'),
#  ('leftist', 'JJ'),
#  ('liar', 'NN'),
#  ('lie', 'JJ'),
#  ('life', 'NN'),
#  ('live', 'JJ'),
#  ('longer', 'RB'),
#  ('low', 'JJ'),
#  ('magazine', 'NN'),
#  ('make', 'VBP'),
#  ('man', 'NN'),
#  ('many', 'JJ'),
#  ('matter', 'NN'),
#  ('mean', 'VBP'),
#  ('medic', 'JJ'),
#  ('merciless', 'NN'),
#  ('mercy', 'NN'),
#  ('more', 'RBR'),
#  ('must', 'MD'),
#  ('necessary', 'JJ'),
#  ('need', 'VB'),
#  ('net', 'JJ'),
#  ('news', 'NN'),
#  ('next', 'IN'),
#  ('nope', 'NN'),
#  ('number', 'NN'),
#  ('nwo', 'JJ'),
#  ('occupy', 'NN'),
#  ('offer', 'NN'),
#  ('old', 'JJ'),
#  ('one', 'CD'),
#  ('openly', 'RB'),
#  ('pandemic', 'JJ'),
#  ('part', 'NN'),
#  ('pay', 'NN'),
#  ('people', 'NNS'),
#  ('perk', 'VBP'),
#  ('perversion', 'NN'),
#  ('pit', 'NN'),
#  ('pizza', 'NN'),
#  ('placed', 'VBD'),
#  ('plan', 'NN'),
#  ('plandemic', 'JJ'),
#  ('politician', 'JJ'),
#  ('position', 'NN'),
#  ('potentially', 'RB'),
#  ('power', 'NN'),
#  ('powerful', 'JJ'),
#  ('prepare', 'NN'),
#  ('problem', 'NN'),
#  ('publish', 'NN'),
#  ('quibble', 'JJ'),
#  ('quick', 'JJ'),
#  ('race', 'NN'),
#  ('read', 'VBD'),
#  ('reap', 'JJ'),
#  ('redpills', 'NNS'),
#  ('referring', 'VBG'),
#  ('remember', 'VB'),
#  ('replacement', 'JJ'),
#  ('retribution', 'NN'),
#  ('revolution', 'NN'),
#  ('rinos', 'FW'),
#  ('rothschild', 'NN'),
#  ('ruling', 'VBG'),
#  ('run', 'VB'),
#  ('sake', 'JJ'),
#  ('satanic', 'JJ'),
#  ('say', 'VBP'),
#  ('saying', 'VBG'),
#  ...]

# %%
doc = 0
feature_index = tfidf[doc,:].nonzero()[1]
tfidf_scores = zip(feature_index, [tfidf[doc, x] for x in feature_index])

for w, s in [(feature_name[i], s) for (i, s) in tfidf_scores]:
  print(w, s)
# Out:
# cigtelegram via 0.1816926890031415
# ht cigtelegram 0.1816926890031415
# caused ht 0.1816926890031415
# globalist caused 0.1816926890031415
# retribution globalist 0.1816926890031415
# want retribution 0.1816926890031415
# thing want 0.1816926890031415
# war thing 0.1816926890031415
# pandemic war 0.1816926890031415
# fake pandemic 0.1816926890031415
# marxism fake 0.1816926890031415
# cultural marxism 0.09814786235181472
# war cultural 0.1816926890031415
# revolution war 0.1816926890031415
# spitted revolution 0.1816926890031415
# swallowed spitted 0.1816926890031415
# generation swallowed 0.1816926890031415
# entire generation 0.1816926890031415
# prepare entire 0.1816926890031415
# break prepare 0.1816926890031415
# war break 0.1816926890031415
# expect war 0.1816926890031415
# potentially expect 0.1816926890031415
# instructive potentially 0.1816926890031415
# war instructive 0.1816926890031415
# experience war 0.1816926890031415
# sharing experience 0.1816926890031415
# man sharing 0.1816926890031415
# ukrainian man 0.1816926890031415
# read ukrainian 0.1816926890031415
# must read 0.1816926890031415
